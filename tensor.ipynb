# %%
import tensorflow as tf
from tensorflow.contrib.tensorboard.plugins import projector
import numpy as np
import gensim

import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')
# Out:
# E:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From E:\Anaconda\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
# E:\Anaconda\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
fname = "w2v_model"
model = gensim.models.keyedvectors.KeyedVectors.load(fname)

# %%
max_size = len(model.wv.vocab)-1

# %%
model.wv.vocab
# Out:
# {'فرانسهای': <gensim.models.keyedvectors.Vocab at 0x2208e5d42e8>,
#  'جماعات': <gensim.models.keyedvectors.Vocab at 0x2208e694e10>,
#  'مکه': <gensim.models.keyedvectors.Vocab at 0x2208e58f080>,
#  'سرش': <gensim.models.keyedvectors.Vocab at 0x2208e3e8400>,
#  'شهرها': <gensim.models.keyedvectors.Vocab at 0x2208e2c2dd8>,
#  'همسایگانش': <gensim.models.keyedvectors.Vocab at 0x2208e58f208>,
#  'استینیتز': <gensim.models.keyedvectors.Vocab at 0x2208e6cdbe0>,
#  'اغلاط': <gensim.models.keyedvectors.Vocab at 0x2208e5577b8>,
#  'فرض': <gensim.models.keyedvectors.Vocab at 0x2208e315128>,
#  'نبردهای': <gensim.models.keyedvectors.Vocab at 0x2208e5965c0>,
#  'گفتاری': <gensim.models.keyedvectors.Vocab at 0x2208e55c278>,
#  'صدیق': <gensim.models.keyedvectors.Vocab at 0x2208e4002e8>,
#  'گوناگون': <gensim.models.keyedvectors.Vocab at 0x2208e426be0>,
#  'مساعد': <gensim.models.keyedvectors.Vocab at 0x2208e2d7f98>,
#  'جهان': <gensim.models.keyedvectors.Vocab at 0x2208dd35a58>,
#  'شاخه': <gensim.models.keyedvectors.Vocab at 0x2208e3ec780>,
#  'محافظهکاران': <gensim.models.keyedvectors.Vocab at 0x2208e60bdd8>,
#  'حجازی': <gensim.models.keyedvectors.Vocab at 0x2208e446e10>,
#  'سودجو': <gensim.models.keyedvectors.Vocab at 0x2208e2d1358>,
#  'درجهان': <gensim.models.keyedvectors.Vocab at 0x2208e3e8278>,
#  'سلامم': <gensim.models.keyedvectors.Vocab at 0x2208e4ff908>,
#  'شکلی': <gensim.models.keyedvectors.Vocab at 0x2208e396710>,
#  'قربانعلی': <gensim.models.keyedvectors.Vocab at 0x2208e3704e0>,
#  'حدودی': <gensim.models.keyedvectors.Vocab at 0x2208e4ce7f0>,
#  'نمیشد': <gensim.models.keyedvectors.Vocab at 0x2208e475a20>,
#  'بزرگراه': <gensim.models.keyedvectors.Vocab at 0x2208e5df470>,
#  'درگیریهایی': <gensim.models.keyedvectors.Vocab at 0x2208e495cf8>,
#  'شوک': <gensim.models.keyedvectors.Vocab at 0x2208e33a2e8>,
#  'ناظران': <gensim.models.keyedvectors.Vocab at 0x2208e596f60>,
#  'همینکه': <gensim.models.keyedvectors.Vocab at 0x2208e536828>,
#  'مدرس': <gensim.models.keyedvectors.Vocab at 0x2208e5d4cf8>,
#  'لزوم': <gensim.models.keyedvectors.Vocab at 0x2208e2b14a8>,
#  'درستی': <gensim.models.keyedvectors.Vocab at 0x2208dd46f60>,
#  'مشابهی': <gensim.models.keyedvectors.Vocab at 0x2208e490b70>,
#  'شاهوردی': <gensim.models.keyedvectors.Vocab at 0x2208e5d46a0>,
#  'رایانه': <gensim.models.keyedvectors.Vocab at 0x2208dd3a5c0>,
#  'بدهکار': <gensim.models.keyedvectors.Vocab at 0x2208e536588>,
#  'متصل': <gensim.models.keyedvectors.Vocab at 0x2208dd3ac50>,
#  'جمال': <gensim.models.keyedvectors.Vocab at 0x2208e418780>,
#  'حذف': <gensim.models.keyedvectors.Vocab at 0x2208e2e2278>,
#  'مادران': <gensim.models.keyedvectors.Vocab at 0x2208e4c89e8>,
#  'فاروج': <gensim.models.keyedvectors.Vocab at 0x2208e67c2e8>,
#  'میرزا': <gensim.models.keyedvectors.Vocab at 0x2208e357438>,
#  'بوتو': <gensim.models.keyedvectors.Vocab at 0x2208e5a7438>,
#  'چارلز': <gensim.models.keyedvectors.Vocab at 0x2208dd589e8>,
#  'قیمت': <gensim.models.keyedvectors.Vocab at 0x2208dd225f8>,
#  'نوبختی': <gensim.models.keyedvectors.Vocab at 0x2208e6afd30>,
#  'اسلاید': <gensim.models.keyedvectors.Vocab at 0x2208e446a20>,
#  'الَّذى': <gensim.models.keyedvectors.Vocab at 0x2208e6a3c50>,
#  'عقاید': <gensim.models.keyedvectors.Vocab at 0x2208e2d7c50>,
#  'بذر': <gensim.models.keyedvectors.Vocab at 0x2208e475908>,
#  'عصبانی': <gensim.models.keyedvectors.Vocab at 0x2208dd3ad68>,
#  'بریتانیای': <gensim.models.keyedvectors.Vocab at 0x2208e536630>,
#  'ولایتی': <gensim.models.keyedvectors.Vocab at 0x2208e4aebe0>,
#  'اندازند': <gensim.models.keyedvectors.Vocab at 0x2208e390e10>,
#  'هنریشه': <gensim.models.keyedvectors.Vocab at 0x2208e5245c0>,
#  'نکردم': <gensim.models.keyedvectors.Vocab at 0x2208e6e1080>,
#  'هوایی': <gensim.models.keyedvectors.Vocab at 0x2208e3a9128>,
#  'سبحانی': <gensim.models.keyedvectors.Vocab at 0x2208e625ac8>,
#  'خر': <gensim.models.keyedvectors.Vocab at 0x2208dd353c8>,
#  'نامزدان': <gensim.models.keyedvectors.Vocab at 0x2208e4d40f0>,
#  'معصیت': <gensim.models.keyedvectors.Vocab at 0x2208e506908>,
#  'استارت': <gensim.models.keyedvectors.Vocab at 0x2208e40d940>,
#  'مهریه': <gensim.models.keyedvectors.Vocab at 0x2208e315780>,
#  'لاستیکی': <gensim.models.keyedvectors.Vocab at 0x2208e4f9278>,
#  'نقره': <gensim.models.keyedvectors.Vocab at 0x2208e4262e8>,
#  'وازخوانان': <gensim.models.keyedvectors.Vocab at 0x2208e5d44a8>,
#  'تثیری': <gensim.models.keyedvectors.Vocab at 0x2208e384a58>,
#  'مس': <gensim.models.keyedvectors.Vocab at 0x2208dd3f320>,
#  'فحشا': <gensim.models.keyedvectors.Vocab at 0x2208e4dfa20>,
#  'کوههای': <gensim.models.keyedvectors.Vocab at 0x2208e3653c8>,
#  'هروین': <gensim.models.keyedvectors.Vocab at 0x2208e6e8240>,
#  'الحاق': <gensim.models.keyedvectors.Vocab at 0x2208e36b198>,
#  'پارلمانی': <gensim.models.keyedvectors.Vocab at 0x2208e32e358>,
#  'تبلیغات': <gensim.models.keyedvectors.Vocab at 0x2208dd58160>,
#  'محلّۀ': <gensim.models.keyedvectors.Vocab at 0x2208e524470>,
#  'دخانی': <gensim.models.keyedvectors.Vocab at 0x2208e6706a0>,
#  'شناسنامه': <gensim.models.keyedvectors.Vocab at 0x2208e3ec9b0>,
#  'ناهماهنگی': <gensim.models.keyedvectors.Vocab at 0x2208e33a908>,
#  'سازمان_ملل': <gensim.models.keyedvectors.Vocab at 0x2208dd58dd8>,
#  'هپبورن': <gensim.models.keyedvectors.Vocab at 0x2208e51d940>,
#  'ردیو': <gensim.models.keyedvectors.Vocab at 0x2208e5a3e48>,
#  'بیداد': <gensim.models.keyedvectors.Vocab at 0x2208e4a9278>,
#  'واعظی': <gensim.models.keyedvectors.Vocab at 0x2208e4a9c50>,
#  'فرانکلین': <gensim.models.keyedvectors.Vocab at 0x2208e52ba20>,
#  'کیانی': <gensim.models.keyedvectors.Vocab at 0x2208e4d9198>,
#  'اتّفاقی': <gensim.models.keyedvectors.Vocab at 0x2208e4ff898>,
#  'مشکوک': <gensim.models.keyedvectors.Vocab at 0x2208e2d12b0>,
#  'فرماندار': <gensim.models.keyedvectors.Vocab at 0x2208dd5f940>,
#  'کلیۀ': <gensim.models.keyedvectors.Vocab at 0x2208e536a20>,
#  'متخلفان': <gensim.models.keyedvectors.Vocab at 0x2208e41d8d0>,
#  'محدودیتهای': <gensim.models.keyedvectors.Vocab at 0x2208e4b4710>,
#  'عاشقان': <gensim.models.keyedvectors.Vocab at 0x2208e6a30b8>,
#  'تعطیل': <gensim.models.keyedvectors.Vocab at 0x2208e3cf6a0>,
#  'بلاتکلیفی': <gensim.models.keyedvectors.Vocab at 0x2208e452208>,
#  'مظنونان': <gensim.models.keyedvectors.Vocab at 0x2208e596780>,
#  'کری': <gensim.models.keyedvectors.Vocab at 0x2208e3cf550>,
#  'انزوای': <gensim.models.keyedvectors.Vocab at 0x2208e44a4e0>,
#  'برلین': <gensim.models.keyedvectors.Vocab at 0x2208e581588>,
#  'فلاح': <gensim.models.keyedvectors.Vocab at 0x2208e4d46a0>,
#  'حجت': <gensim.models.keyedvectors.Vocab at 0x2208e2b1240>,
#  'ژنو': <gensim.models.keyedvectors.Vocab at 0x2208e3ec5c0>,
#  'قنات': <gensim.models.keyedvectors.Vocab at 0x2208e351eb8>,
#  'لوداب': <gensim.models.keyedvectors.Vocab at 0x2208e2c22e8>,
#  'کمیسیونهای': <gensim.models.keyedvectors.Vocab at 0x2208e482b00>,
#  'کارگاهان': <gensim.models.keyedvectors.Vocab at 0x2208e6680b8>,
#  'اشراف': <gensim.models.keyedvectors.Vocab at 0x2208e5306a0>,
#  'واحدها': <gensim.models.keyedvectors.Vocab at 0x2208e676c50>,
#  'ملک': <gensim.models.keyedvectors.Vocab at 0x2208e37c160>,
#  'ارتشی': <gensim.models.keyedvectors.Vocab at 0x2208e5bb710>,
#  'بهرههاى': <gensim.models.keyedvectors.Vocab at 0x2208e6af1d0>,
#  'اولینبار': <gensim.models.keyedvectors.Vocab at 0x2208e4b47f0>,
#  'بندگانت': <gensim.models.keyedvectors.Vocab at 0x2208e64add8>,
#  'دبستانی': <gensim.models.keyedvectors.Vocab at 0x2208e5577f0>,
#  'استعداد': <gensim.models.keyedvectors.Vocab at 0x2208e2b62b0>,
#  'مطلقا': <gensim.models.keyedvectors.Vocab at 0x2208e482a58>,
#  'اعتمادی': <gensim.models.keyedvectors.Vocab at 0x2208e3fa320>,
#  'بنجامین': <gensim.models.keyedvectors.Vocab at 0x2208e52bd68>,
#  'دانستند': <gensim.models.keyedvectors.Vocab at 0x2208e377d68>,
#  'قرمز': <gensim.models.keyedvectors.Vocab at 0x2208e34c780>,
#  'واقعیت': <gensim.models.keyedvectors.Vocab at 0x2208e2efcf8>,
#  'نشستم': <gensim.models.keyedvectors.Vocab at 0x2208e4df048>,
#  'الماس': <gensim.models.keyedvectors.Vocab at 0x2208e51df60>,
#  'جاذبه': <gensim.models.keyedvectors.Vocab at 0x2208e2c2a90>,
#  'بهاستثنای': <gensim.models.keyedvectors.Vocab at 0x2208e6255f8>,
#  'نشستی': <gensim.models.keyedvectors.Vocab at 0x2208e2ef7b8>,
#  'تقدیر': <gensim.models.keyedvectors.Vocab at 0x2208dd5f358>,
#  'ایراد': <gensim.models.keyedvectors.Vocab at 0x2208e53e898>,
#  'امارات': <gensim.models.keyedvectors.Vocab at 0x2208e2eaac8>,
#  'علاقهمندم': <gensim.models.keyedvectors.Vocab at 0x2208e43e908>,
#  'استبخش': <gensim.models.keyedvectors.Vocab at 0x2208e5c2e48>,
#  'نمای': <gensim.models.keyedvectors.Vocab at 0x2208e35f390>,
#  'دانسته': <gensim.models.keyedvectors.Vocab at 0x2208e3cfb70>,
#  'وارگی': <gensim.models.keyedvectors.Vocab at 0x2208e4df940>,
#  'زادگاهم': <gensim.models.keyedvectors.Vocab at 0x2208e5e5128>,
#  'قیامت': <gensim.models.keyedvectors.Vocab at 0x2208e53edd8>,
#  'ببندند': <gensim.models.keyedvectors.Vocab at 0x2208e3cfc50>,
#  'مجرد': <gensim.models.keyedvectors.Vocab at 0x2208e6d5cc0>,
#  'مبتلابه': <gensim.models.keyedvectors.Vocab at 0x2208e6d55f8>,
#  'احتیاط': <gensim.models.keyedvectors.Vocab at 0x2208e3f3780>,
#  'العرب': <gensim.models.keyedvectors.Vocab at 0x2208e58fcf8>,
#  'جشنهای': <gensim.models.keyedvectors.Vocab at 0x2208e5cd208>,
#  'طرفانه': <gensim.models.keyedvectors.Vocab at 0x2208e3e8470>,
#  'موختگان': <gensim.models.keyedvectors.Vocab at 0x2208e670518>,
#  'نوزدهم': <gensim.models.keyedvectors.Vocab at 0x2208e4bba20>,
#  'راضی': <gensim.models.keyedvectors.Vocab at 0x2208dd3af60>,
#  'بیداری٬': <gensim.models.keyedvectors.Vocab at 0x2208e6767f0>,
#  'هنگفتی': <gensim.models.keyedvectors.Vocab at 0x2208e65d048>,
#  'ضدفتاب': <gensim.models.keyedvectors.Vocab at 0x2208e2efc88>,
#  'پخش': <gensim.models.keyedvectors.Vocab at 0x2208e2ef198>,
#  'ید': <gensim.models.keyedvectors.Vocab at 0x2208dd4c6a0>,
#  'عصر': <gensim.models.keyedvectors.Vocab at 0x2208e32e198>,
#  'کنفوسیوس': <gensim.models.keyedvectors.Vocab at 0x2208e53e438>,
#  'داعیه': <gensim.models.keyedvectors.Vocab at 0x2208e4bbbe0>,
#  'سیار': <gensim.models.keyedvectors.Vocab at 0x2208e370ba8>,
#  'واریز': <gensim.models.keyedvectors.Vocab at 0x2208e3703c8>,
#  'ارجنان': <gensim.models.keyedvectors.Vocab at 0x2208e357400>,
#  'لَکَ': <gensim.models.keyedvectors.Vocab at 0x2208e6a9390>,
#  'نمونههای': <gensim.models.keyedvectors.Vocab at 0x2208e644358>,
#  'شعر': <gensim.models.keyedvectors.Vocab at 0x2208e446128>,
#  'بدیهیات': <gensim.models.keyedvectors.Vocab at 0x2208e6cddd8>,
#  'پرفروش': <gensim.models.keyedvectors.Vocab at 0x2208e45c208>,
#  'ولادتش': <gensim.models.keyedvectors.Vocab at 0x2208e6a3be0>,
#  'جلوه': <gensim.models.keyedvectors.Vocab at 0x2208e315a90>,
#  'ببینیم': <gensim.models.keyedvectors.Vocab at 0x2208e30f940>,
#  'حالاست': <gensim.models.keyedvectors.Vocab at 0x2208e5177b8>,
#  'وزیر_خارجه': <gensim.models.keyedvectors.Vocab at 0x2208e32ee80>,
#  'بازیگران': <gensim.models.keyedvectors.Vocab at 0x2208e40dc50>,
#  'یازدهم': <gensim.models.keyedvectors.Vocab at 0x2208dd284a8>,
#  'لطمه': <gensim.models.keyedvectors.Vocab at 0x2208e2d1400>,
#  'فوجی': <gensim.models.keyedvectors.Vocab at 0x2208e5b5780>,
#  'رکورددار': <gensim.models.keyedvectors.Vocab at 0x2208e2bd048>,
#  'کارگیری': <gensim.models.keyedvectors.Vocab at 0x2208e31ae48>,
#  'ار': <gensim.models.keyedvectors.Vocab at 0x2208e581eb8>,
#  'چنگ': <gensim.models.keyedvectors.Vocab at 0x2208e576128>,
#  'یتالله': <gensim.models.keyedvectors.Vocab at 0x2208e470be0>,
#  'روزیم': <gensim.models.keyedvectors.Vocab at 0x2208e6a95f8>,
#  'یادواره': <gensim.models.keyedvectors.Vocab at 0x2208e67c128>,
#  'پند': <gensim.models.keyedvectors.Vocab at 0x2208e470710>,
#  'بیکسی': <gensim.models.keyedvectors.Vocab at 0x2208e4f9828>,
#  'ترافیک': <gensim.models.keyedvectors.Vocab at 0x2208e475fd0>,
#  'ناپذیر': <gensim.models.keyedvectors.Vocab at 0x2208e4ce710>,
#  'مطلع': <gensim.models.keyedvectors.Vocab at 0x2208dd3acc0>,
#  'چوبی': <gensim.models.keyedvectors.Vocab at 0x2208e452eb8>,
#  'هایاین': <gensim.models.keyedvectors.Vocab at 0x2208e2b1ba8>,
#  'نوجوانها': <gensim.models.keyedvectors.Vocab at 0x2208e53e8d0>,
#  'السلام': <gensim.models.keyedvectors.Vocab at 0x2208e62a358>,
#  'اوّلی': <gensim.models.keyedvectors.Vocab at 0x2208e4f9d68>,
#  'غذا': <gensim.models.keyedvectors.Vocab at 0x2208dd58da0>,
#  'اوین': <gensim.models.keyedvectors.Vocab at 0x2208e5f8b70>,
#  'زیرکشت': <gensim.models.keyedvectors.Vocab at 0x2208e6bb7b8>,
#  'باخته': <gensim.models.keyedvectors.Vocab at 0x2208e4c8198>,
#  'محرومین': <gensim.models.keyedvectors.Vocab at 0x2208e68e588>,
#  'خودساختگانِ': <gensim.models.keyedvectors.Vocab at 0x2208e536668>,
#  'تابعه': <gensim.models.keyedvectors.Vocab at 0x2208e687128>,
#  'عطاران': <gensim.models.keyedvectors.Vocab at 0x2208e664f60>,
#  'طاها': <gensim.models.keyedvectors.Vocab at 0x2208e446dd8>,
#  'مدار': <gensim.models.keyedvectors.Vocab at 0x2208e3e22b0>,
#  'کمپین': <gensim.models.keyedvectors.Vocab at 0x2208e4a2b00>,
#  'سازگاری': <gensim.models.keyedvectors.Vocab at 0x2208e326630>,
#  'ظروف': <gensim.models.keyedvectors.Vocab at 0x2208e6c1a20>,
#  'مطالعه': <gensim.models.keyedvectors.Vocab at 0x2208e3706a0>,
#  'یارانش': <gensim.models.keyedvectors.Vocab at 0x2208e67c240>,
#  'تولید': <gensim.models.keyedvectors.Vocab at 0x2208e2c2668>,
#  'زندانیان': <gensim.models.keyedvectors.Vocab at 0x2208e3156a0>,
#  'قراردادی': <gensim.models.keyedvectors.Vocab at 0x2208e4909e8>,
#  'قیافۀ': <gensim.models.keyedvectors.Vocab at 0x2208e4d98d0>,
#  'ساختمان': <gensim.models.keyedvectors.Vocab at 0x2208e351390>,
#  'رکعت': <gensim.models.keyedvectors.Vocab at 0x2208e6a9ac8>,
#  'فتهای': <gensim.models.keyedvectors.Vocab at 0x2208e6da0f0>,
#  'الهیات': <gensim.models.keyedvectors.Vocab at 0x2208e63d5c0>,
#  'کرانه': <gensim.models.keyedvectors.Vocab at 0x2208e589588>,
#  'بازنگری': <gensim.models.keyedvectors.Vocab at 0x2208e31a898>,
#  'ایستگاه': <gensim.models.keyedvectors.Vocab at 0x2208e4ff320>,
#  'کالاهای': <gensim.models.keyedvectors.Vocab at 0x2208e4aef28>,
#  'حد': <gensim.models.keyedvectors.Vocab at 0x2208e2aa940>,
#  'اصولگرایان': <gensim.models.keyedvectors.Vocab at 0x2208e333d68>,
#  'همزیستی': <gensim.models.keyedvectors.Vocab at 0x2208e5b5cc0>,
#  'سالهایی': <gensim.models.keyedvectors.Vocab at 0x2208e326eb8>,
#  'خضر': <gensim.models.keyedvectors.Vocab at 0x2208e63d6d8>,
#  'پخت': <gensim.models.keyedvectors.Vocab at 0x2208e39c518>,
#  'تاثیرگذاری': <gensim.models.keyedvectors.Vocab at 0x2208e38a400>,
#  'معظم': <gensim.models.keyedvectors.Vocab at 0x2208e2d1940>,
#  'اقتدار': <gensim.models.keyedvectors.Vocab at 0x2208dd587b8>,
#  'شیعی': <gensim.models.keyedvectors.Vocab at 0x2208e45cc88>,
#  'زارانی': <gensim.models.keyedvectors.Vocab at 0x2208e345c18>,
#  'انبیا': <gensim.models.keyedvectors.Vocab at 0x2208e42bc18>,
#  'اشعه': <gensim.models.keyedvectors.Vocab at 0x2208e2f62b0>,
#  'زمزمه': <gensim.models.keyedvectors.Vocab at 0x2208e63dba8>,
#  'اولادی': <gensim.models.keyedvectors.Vocab at 0x2208e60b3c8>,
#  'ستم': <gensim.models.keyedvectors.Vocab at 0x2208e2b1748>,
#  'انداخته': <gensim.models.keyedvectors.Vocab at 0x2208e3d41d0>,
#  'ظهورش': <gensim.models.keyedvectors.Vocab at 0x2208e4f3518>,
#  'بشود': <gensim.models.keyedvectors.Vocab at 0x2208e315630>,
#  'برسان': <gensim.models.keyedvectors.Vocab at 0x2208e6501d0>,
#  'شانزده': <gensim.models.keyedvectors.Vocab at 0x2208e517f28>,
#  'افتخاری': <gensim.models.keyedvectors.Vocab at 0x2208e5c8f28>,
#  'جاست': <gensim.models.keyedvectors.Vocab at 0x2208e6c13c8>,
#  'فضایل': <gensim.models.keyedvectors.Vocab at 0x2208e2aac50>,
#  'گذاشتن': <gensim.models.keyedvectors.Vocab at 0x2208e50a128>,
#  'ناکارمدی': <gensim.models.keyedvectors.Vocab at 0x2208e4d4780>,
#  'اسماعیلی': <gensim.models.keyedvectors.Vocab at 0x2208e4525c0>,
#  'هنگکنگ': <gensim.models.keyedvectors.Vocab at 0x2208e687ba8>,
#  'تعارفات': <gensim.models.keyedvectors.Vocab at 0x2208e40d978>,
#  'نقشش': <gensim.models.keyedvectors.Vocab at 0x2208e4a2e10>,
#  'وزنه': <gensim.models.keyedvectors.Vocab at 0x2208e5df668>,
#  'سلفچگان': <gensim.models.keyedvectors.Vocab at 0x2208e625898>,
#  'اندیشمندان': <gensim.models.keyedvectors.Vocab at 0x2208e5c2400>,
#  'کامکار': <gensim.models.keyedvectors.Vocab at 0x2208e458e10>,
#  'طراوت': <gensim.models.keyedvectors.Vocab at 0x2208e56af60>,
#  'ترسم': <gensim.models.keyedvectors.Vocab at 0x2208e544d30>,
#  'مناسبتی': <gensim.models.keyedvectors.Vocab at 0x2208e557b38>,
#  'کبودوال': <gensim.models.keyedvectors.Vocab at 0x2208e39c1d0>,
#  'شرطی': <gensim.models.keyedvectors.Vocab at 0x2208e3960b8>,
#  'لاپوشانی': <gensim.models.keyedvectors.Vocab at 0x2208e67ce80>,
#  'دوستان_سوریه': <gensim.models.keyedvectors.Vocab at 0x2208e3e8f98>,
#  'بیمارستانی': <gensim.models.keyedvectors.Vocab at 0x2208e49bcc0>,
#  'بردم': <gensim.models.keyedvectors.Vocab at 0x2208e524cf8>,
#  'گراست': <gensim.models.keyedvectors.Vocab at 0x2208e6c8a58>,
#  'دختر': <gensim.models.keyedvectors.Vocab at 0x2208e437e48>,
#  'فرستنده': <gensim.models.keyedvectors.Vocab at 0x2208e5964a8>,
#  'ماندن': <gensim.models.keyedvectors.Vocab at 0x2208e3f3438>,
#  'مدارک': <gensim.models.keyedvectors.Vocab at 0x2208e3da588>,
#  'نکتهای': <gensim.models.keyedvectors.Vocab at 0x2208e5eeb00>,
#  'بنیادگرای': <gensim.models.keyedvectors.Vocab at 0x2208e681978>,
#  'بیگانه': <gensim.models.keyedvectors.Vocab at 0x2208e345208>,
#  'انیمیشن': <gensim.models.keyedvectors.Vocab at 0x2208e45c438>,
#  'برید': <gensim.models.keyedvectors.Vocab at 0x2208dd1db38>,
#  'گول': <gensim.models.keyedvectors.Vocab at 0x2208e4d9630>,
#  'راجع': <gensim.models.keyedvectors.Vocab at 0x2208e37c470>,
#  'قاه': <gensim.models.keyedvectors.Vocab at 0x2208e536278>,
#  'دختران': <gensim.models.keyedvectors.Vocab at 0x2208e3afbe0>,
#  'بخشنده': <gensim.models.keyedvectors.Vocab at 0x2208e65dc50>,
#  'مطلق': <gensim.models.keyedvectors.Vocab at 0x2208e482710>,
#  'تندی': <gensim.models.keyedvectors.Vocab at 0x2208dd3a6d8>,
#  'پرسیده': <gensim.models.keyedvectors.Vocab at 0x2208e333390>,
#  'تسیس': <gensim.models.keyedvectors.Vocab at 0x2208e308c50>,
#  'فیلمم': <gensim.models.keyedvectors.Vocab at 0x2208e5cdc88>,
#  'عقلانیت': <gensim.models.keyedvectors.Vocab at 0x2208e475d30>,
#  'نفیسی': <gensim.models.keyedvectors.Vocab at 0x2208e446da0>,
#  'همرنگ': <gensim.models.keyedvectors.Vocab at 0x2208e5366a0>,
#  'مصوب': <gensim.models.keyedvectors.Vocab at 0x2208e2b6160>,
#  'شفاف': <gensim.models.keyedvectors.Vocab at 0x2208dd2d5f8>,
#  'صنعتگران': <gensim.models.keyedvectors.Vocab at 0x2208e3846d8>,
#  'برداشتم': <gensim.models.keyedvectors.Vocab at 0x2208e4d9c88>,
#  'نقطۀ': <gensim.models.keyedvectors.Vocab at 0x2208e4e6470>,
#  'جبهههای': <gensim.models.keyedvectors.Vocab at 0x2208e67c198>,
#  'وعدههایی': <gensim.models.keyedvectors.Vocab at 0x2208e452da0>,
#  'توجه': <gensim.models.keyedvectors.Vocab at 0x2208dd22eb8>,
#  'شاکیان': <gensim.models.keyedvectors.Vocab at 0x2208e2d1128>,
#  'ببرد': <gensim.models.keyedvectors.Vocab at 0x2208e2eafd0>,
#  'فضاهای': <gensim.models.keyedvectors.Vocab at 0x2208e357da0>,
#  'تاگس': <gensim.models.keyedvectors.Vocab at 0x2208e6e84e0>,
#  'گردو': <gensim.models.keyedvectors.Vocab at 0x2208e2c26a0>,
#  'سروصدای': <gensim.models.keyedvectors.Vocab at 0x2208e3e2400>,
#  'مشورت': <gensim.models.keyedvectors.Vocab at 0x2208e3dad68>,
#  'موقوفاتی': <gensim.models.keyedvectors.Vocab at 0x2208e431c50>,
#  'هوشمند': <gensim.models.keyedvectors.Vocab at 0x2208e488ef0>,
#  'ابهر': <gensim.models.keyedvectors.Vocab at 0x2208e3652e8>,
#  'محصور': <gensim.models.keyedvectors.Vocab at 0x2208e6dac18>,
#  'والایی': <gensim.models.keyedvectors.Vocab at 0x2208e5126d8>,
#  'بازاری': <gensim.models.keyedvectors.Vocab at 0x2208e4d47f0>,
#  'بابیان': <gensim.models.keyedvectors.Vocab at 0x2208e4642e8>,
#  'تسنن': <gensim.models.keyedvectors.Vocab at 0x2208e644240>,
#  'داماد': <gensim.models.keyedvectors.Vocab at 0x2208e326b38>,
#  'متنوع': <gensim.models.keyedvectors.Vocab at 0x2208dd5f278>,
#  'تهران': <gensim.models.keyedvectors.Vocab at 0x2208dd22710>,
#  'حدیث': <gensim.models.keyedvectors.Vocab at 0x2208e524898>,
#  'فرصت': <gensim.models.keyedvectors.Vocab at 0x2208dd53908>,
#  'ذهنتان': <gensim.models.keyedvectors.Vocab at 0x2208e488eb8>,
#  'وَاجْعَلْنى': <gensim.models.keyedvectors.Vocab at 0x2208e6a9ef0>,
#  'سیبهایی': <gensim.models.keyedvectors.Vocab at 0x2208e464ef0>,
#  'جمالی': <gensim.models.keyedvectors.Vocab at 0x2208e36bc88>,
#  'بینم': <gensim.models.keyedvectors.Vocab at 0x2208e4bbb70>,
#  'گرمی': <gensim.models.keyedvectors.Vocab at 0x2208e38aa90>,
#  'ینه': <gensim.models.keyedvectors.Vocab at 0x2208e357390>,
#  'انبوه': <gensim.models.keyedvectors.Vocab at 0x2208e2c2e80>,
#  'مکلف': <gensim.models.keyedvectors.Vocab at 0x2208e5f8c50>,
#  'ومردم': <gensim.models.keyedvectors.Vocab at 0x2208e62aeb8>,
#  'لاتین': <gensim.models.keyedvectors.Vocab at 0x2208e5309e8>,
#  'کنسرسیوم': <gensim.models.keyedvectors.Vocab at 0x2208e490c18>,
#  'پرشی': <gensim.models.keyedvectors.Vocab at 0x2208e4bb710>,
#  'خالکوبی': <gensim.models.keyedvectors.Vocab at 0x2208e517dd8>,
#  'مشهدی': <gensim.models.keyedvectors.Vocab at 0x2208e390ac8>,
#  'سهامدار': <gensim.models.keyedvectors.Vocab at 0x2208e4ceda0>,
#  'اعتنایی': <gensim.models.keyedvectors.Vocab at 0x2208e333908>,
#  'شهرستانهای': <gensim.models.keyedvectors.Vocab at 0x2208e452668>,
#  'زینت': <gensim.models.keyedvectors.Vocab at 0x2208e5240f0>,
#  'بازنشستگانی': <gensim.models.keyedvectors.Vocab at 0x2208e6a3240>,
#  'بازیکن': <gensim.models.keyedvectors.Vocab at 0x2208e2eaf28>,
#  'بو': <gensim.models.keyedvectors.Vocab at 0x2208e400358>,
#  'رام': <gensim.models.keyedvectors.Vocab at 0x2208dd539e8>,
#  'جاده': <gensim.models.keyedvectors.Vocab at 0x2208e2bdf28>,
#  'پناهگاه': <gensim.models.keyedvectors.Vocab at 0x2208e35f8d0>,
#  'سیب': <gensim.models.keyedvectors.Vocab at 0x2208dd3a8d0>,
#  'گزارشاتی': <gensim.models.keyedvectors.Vocab at 0x2208e308320>,
#  'خاطر': <gensim.models.keyedvectors.Vocab at 0x2208dd58c50>,
#  'نزده': <gensim.models.keyedvectors.Vocab at 0x2208e6e1a58>,
#  'نگیرند': <gensim.models.keyedvectors.Vocab at 0x2208e3cf860>,
#  'فرهنگى': <gensim.models.keyedvectors.Vocab at 0x2208e611160>,
#  'جمهور': <gensim.models.keyedvectors.Vocab at 0x2208dd4c198>,
#  'فهمد': <gensim.models.keyedvectors.Vocab at 0x2208e54aa90>,
#  'جابر': <gensim.models.keyedvectors.Vocab at 0x2208e495be0>,
#  'لبخند': <gensim.models.keyedvectors.Vocab at 0x2208e4d9cf8>,
#  'جوابش': <gensim.models.keyedvectors.Vocab at 0x2208e5509b0>,
#  'عدالتی': <gensim.models.keyedvectors.Vocab at 0x2208e2aa5f8>,
#  'موردمربوط': <gensim.models.keyedvectors.Vocab at 0x2208e60beb8>,
#  'انگیزهای': <gensim.models.keyedvectors.Vocab at 0x2208e5ee6d8>,
#  'پشتش': <gensim.models.keyedvectors.Vocab at 0x2208e55cf28>,
#  'قصاص': <gensim.models.keyedvectors.Vocab at 0x2208e2aa1d0>,
#  'احتساب': <gensim.models.keyedvectors.Vocab at 0x2208e413be0>,
#  'بشریت': <gensim.models.keyedvectors.Vocab at 0x2208e42bb00>,
#  'هلند': <gensim.models.keyedvectors.Vocab at 0x2208e4c2748>,
#  'چارهای': <gensim.models.keyedvectors.Vocab at 0x2208e47d5c0>,
#  'رحمتت': <gensim.models.keyedvectors.Vocab at 0x2208e6508d0>,
#  'رودک': <gensim.models.keyedvectors.Vocab at 0x2208e41d550>,
#  'نال': <gensim.models.keyedvectors.Vocab at 0x2208e2a5f60>,
#  'مبارزه': <gensim.models.keyedvectors.Vocab at 0x2208e308748>,
#  'مادرهای': <gensim.models.keyedvectors.Vocab at 0x2208e4df198>,
#  'میبرد': <gensim.models.keyedvectors.Vocab at 0x2208e47d438>,
#  'ناجی': <gensim.models.keyedvectors.Vocab at 0x2208e464a20>,
#  'اسپری': <gensim.models.keyedvectors.Vocab at 0x2208e6bbd68>,
#  'عسگراولادی': <gensim.models.keyedvectors.Vocab at 0x2208e60b358>,
#  'سانسکریت': <gensim.models.keyedvectors.Vocab at 0x2208e512550>,
#  'فکرشان': <gensim.models.keyedvectors.Vocab at 0x2208e53e080>,
#  'تری': <gensim.models.keyedvectors.Vocab at 0x2208dd2d278>,
#  'مرحومه': <gensim.models.keyedvectors.Vocab at 0x2208e5249e8>,
#  'لغت': <gensim.models.keyedvectors.Vocab at 0x2208e530c50>,
#  'اکبری': <gensim.models.keyedvectors.Vocab at 0x2208e3a91d0>,
#  'مغازه': <gensim.models.keyedvectors.Vocab at 0x2208e54af60>,
#  'حامیان': <gensim.models.keyedvectors.Vocab at 0x2208e326400>,
#  'دلیری': <gensim.models.keyedvectors.Vocab at 0x2208e377208>,
#  'حوضه': <gensim.models.keyedvectors.Vocab at 0x2208e365898>,
#  'روزافزون': <gensim.models.keyedvectors.Vocab at 0x2208e37c320>,
#  'پزشک': <gensim.models.keyedvectors.Vocab at 0x2208e2cbdd8>,
#  'برمد': <gensim.models.keyedvectors.Vocab at 0x2208e57bef0>,
#  'ارز': <gensim.models.keyedvectors.Vocab at 0x2208dd22208>,
#  'فرهنگ_ارشاد': <gensim.models.keyedvectors.Vocab at 0x2208e2d7940>,
#  'وکالت': <gensim.models.keyedvectors.Vocab at 0x2208e30f048>,
#  'گیران': <gensim.models.keyedvectors.Vocab at 0x2208e3775c0>,
#  'کمیاب': <gensim.models.keyedvectors.Vocab at 0x2208e67c9e8>,
#  'گندم': <gensim.models.keyedvectors.Vocab at 0x2208e36b278>,
#  'کیلو': <gensim.models.keyedvectors.Vocab at 0x2208e4189e8>,
#  'دریانوردان': <gensim.models.keyedvectors.Vocab at 0x2208e6184a8>,
#  'گوش': <gensim.models.keyedvectors.Vocab at 0x2208e3d4a90>,
#  'همپیمانان': <gensim.models.keyedvectors.Vocab at 0x2208e482c18>,
#  'اسامه': <gensim.models.keyedvectors.Vocab at 0x2208e5bbbe0>,
#  'فیلمنامه': <gensim.models.keyedvectors.Vocab at 0x2208e5cdd30>,
#  'تبلیغ': <gensim.models.keyedvectors.Vocab at 0x2208e3cfe10>,
#  'روستای': <gensim.models.keyedvectors.Vocab at 0x2208e2b6e10>,
#  'عصبی': <gensim.models.keyedvectors.Vocab at 0x2208e6709b0>,
#  'تهمت': <gensim.models.keyedvectors.Vocab at 0x2208e33a550>,
#  'سینماگران': <gensim.models.keyedvectors.Vocab at 0x2208e3fac18>,
#  'سینماها': <gensim.models.keyedvectors.Vocab at 0x2208e4379e8>,
#  'متبوعش': <gensim.models.keyedvectors.Vocab at 0x2208e65d7f0>,
#  'بادی': <gensim.models.keyedvectors.Vocab at 0x2208e326be0>,
#  'پرداخته': <gensim.models.keyedvectors.Vocab at 0x2208e2efd30>,
#  'باستان': <gensim.models.keyedvectors.Vocab at 0x2208e35fc50>,
#  'کت': <gensim.models.keyedvectors.Vocab at 0x2208e326908>,
#  'عزادار': <gensim.models.keyedvectors.Vocab at 0x2208dd46e10>,
#  'کنش': <gensim.models.keyedvectors.Vocab at 0x2208e3bc518>,
#  'لویس': <gensim.models.keyedvectors.Vocab at 0x2208e2fbba8>,
#  'شریف': <gensim.models.keyedvectors.Vocab at 0x2208e3f3358>,
#  'خیابانهای': <gensim.models.keyedvectors.Vocab at 0x2208e47dd30>,
#  'لیبیا': <gensim.models.keyedvectors.Vocab at 0x2208e5c86a0>,
#  'سخنی': <gensim.models.keyedvectors.Vocab at 0x2208e3332b0>,
#  'سخنورانی': <gensim.models.keyedvectors.Vocab at 0x2208e53e5f8>,
#  'گشاده': <gensim.models.keyedvectors.Vocab at 0x2208e4e6f60>,
#  'سفارش': <gensim.models.keyedvectors.Vocab at 0x2208e4374e0>,
#  'فرصتهاو': <gensim.models.keyedvectors.Vocab at 0x2208e46b320>,
#  'رابسون': <gensim.models.keyedvectors.Vocab at 0x2208e517358>,
#  'پیر': <gensim.models.keyedvectors.Vocab at 0x2208e413048>,
#  'میتوانید': <gensim.models.keyedvectors.Vocab at 0x2208e4c2470>,
#  'الاقصر': <gensim.models.keyedvectors.Vocab at 0x2208e6bb240>,
#  'سیاسیون': <gensim.models.keyedvectors.Vocab at 0x2208e333978>,
#  'متمول': <gensim.models.keyedvectors.Vocab at 0x2208e596390>,
#  'انعکاس': <gensim.models.keyedvectors.Vocab at 0x2208e31af60>,
#  'منفی': <gensim.models.keyedvectors.Vocab at 0x2208e2bdb00>,
#  'ذَرَّة': <gensim.models.keyedvectors.Vocab at 0x2208e631470>,
#  'لینک': <gensim.models.keyedvectors.Vocab at 0x2208e3a4e80>,
#  'پرکره': <gensim.models.keyedvectors.Vocab at 0x2208e6e81d0>,
#  'دمید': <gensim.models.keyedvectors.Vocab at 0x2208e3af5f8>,
#  'بازیکنان': <gensim.models.keyedvectors.Vocab at 0x2208e2e2c18>,
#  'استانی': <gensim.models.keyedvectors.Vocab at 0x2208e33f4e0>,
#  'نوجوان': <gensim.models.keyedvectors.Vocab at 0x2208e55cac8>,
#  'محرومیت': <gensim.models.keyedvectors.Vocab at 0x2208e5db0b8>,
#  'نامدار': <gensim.models.keyedvectors.Vocab at 0x2208e6872b0>,
#  'همگرایی': <gensim.models.keyedvectors.Vocab at 0x2208e38a908>,
#  'اردوگاه': <gensim.models.keyedvectors.Vocab at 0x2208e33feb8>,
#  'شریک': <gensim.models.keyedvectors.Vocab at 0x2208e333eb8>,
#  'دمخواران': <gensim.models.keyedvectors.Vocab at 0x2208e544a90>,
#  'غلبه': <gensim.models.keyedvectors.Vocab at 0x2208e3a9ba8>,
#  'وریم': <gensim.models.keyedvectors.Vocab at 0x2208e3c1c88>,
#  'اعظم': <gensim.models.keyedvectors.Vocab at 0x2208e2cb4e0>,
#  'سجادپور': <gensim.models.keyedvectors.Vocab at 0x2208e6a3668>,
#  'نجای': <gensim.models.keyedvectors.Vocab at 0x2208e54a898>,
#  'سفته': <gensim.models.keyedvectors.Vocab at 0x2208dd28550>,
#  'میتوان': <gensim.models.keyedvectors.Vocab at 0x2208e2ddf28>,
#  'غم': <gensim.models.keyedvectors.Vocab at 0x2208e42b630>,
#  'امپراتوری': <gensim.models.keyedvectors.Vocab at 0x2208e5062b0>,
#  'اروپاست': <gensim.models.keyedvectors.Vocab at 0x2208e576e80>,
#  'زدایی': <gensim.models.keyedvectors.Vocab at 0x2208dd2d630>,
#  'بهنظر': <gensim.models.keyedvectors.Vocab at 0x2208e5ee630>,
#  'انعقاد': <gensim.models.keyedvectors.Vocab at 0x2208e6cd208>,
#  'دیالوگ': <gensim.models.keyedvectors.Vocab at 0x2208dd53b00>,
#  'جایگاهی': <gensim.models.keyedvectors.Vocab at 0x2208e3fa2e8>,
#  'همیشگی': <gensim.models.keyedvectors.Vocab at 0x2208e3a4860>,
#  'سگان': <gensim.models.keyedvectors.Vocab at 0x2208e4ee080>,
#  'بَیْنَنا': <gensim.models.keyedvectors.Vocab at 0x2208e6a9208>,
#  'ربوبیت': <gensim.models.keyedvectors.Vocab at 0x2208e62a8d0>,
#  'ارباب': <gensim.models.keyedvectors.Vocab at 0x2208e301828>,
#  'غلام': <gensim.models.keyedvectors.Vocab at 0x2208e6b5390>,
#  'صرف': <gensim.models.keyedvectors.Vocab at 0x2208e31a9e8>,
#  'پرونده': <gensim.models.keyedvectors.Vocab at 0x2208dd53860>,
#  'محکمی': <gensim.models.keyedvectors.Vocab at 0x2208e4c8d30>,
#  'بغدادی': <gensim.models.keyedvectors.Vocab at 0x2208e69d320>,
#  'چرندیات': <gensim.models.keyedvectors.Vocab at 0x2208e53e160>,
#  'اطلاع': <gensim.models.keyedvectors.Vocab at 0x2208dd3f208>,
#  'ثانیه': <gensim.models.keyedvectors.Vocab at 0x2208e42b5f8>,
#  'تبع': <gensim.models.keyedvectors.Vocab at 0x2208dd223c8>,
#  'الشعاع': <gensim.models.keyedvectors.Vocab at 0x2208e3cf6d8>,
#  'الطّاهِرینَ': <gensim.models.keyedvectors.Vocab at 0x2208e6af780>,
#  'بورسیه': <gensim.models.keyedvectors.Vocab at 0x2208e5d4898>,
#  'جشنوارهها': <gensim.models.keyedvectors.Vocab at 0x2208e44af98>,
#  'بری': <gensim.models.keyedvectors.Vocab at 0x2208e668198>,
#  'ناجا': <gensim.models.keyedvectors.Vocab at 0x2208e6877f0>,
#  'غریبی': <gensim.models.keyedvectors.Vocab at 0x2208e5f80b8>,
#  'شروانی': <gensim.models.keyedvectors.Vocab at 0x2208e506da0>,
#  'ناملموس': <gensim.models.keyedvectors.Vocab at 0x2208e6e87f0>,
#  'اسوتلانا': <gensim.models.keyedvectors.Vocab at 0x2208e3e8198>,
#  'تختی': <gensim.models.keyedvectors.Vocab at 0x2208e6b5c50>,
#  'اعتباری': <gensim.models.keyedvectors.Vocab at 0x2208e490c88>,
#  'طوسیگیانی': <gensim.models.keyedvectors.Vocab at 0x2208e544198>,
#  'پاش': <gensim.models.keyedvectors.Vocab at 0x2208e51d1d0>,
#  'تجسم': <gensim.models.keyedvectors.Vocab at 0x2208e4ce048>,
#  'قبیل': <gensim.models.keyedvectors.Vocab at 0x2208dd467f0>,
#  'زمین': <gensim.models.keyedvectors.Vocab at 0x2208e2b15c0>,
#  'سکولاریسم': <gensim.models.keyedvectors.Vocab at 0x2208e5af860>,
#  'سرمنزل': <gensim.models.keyedvectors.Vocab at 0x2208e50a940>,
#  'یکم': <gensim.models.keyedvectors.Vocab at 0x2208e3843c8>,
#  'لای': <gensim.models.keyedvectors.Vocab at 0x2208e357860>,
#  'شورشیان': <gensim.models.keyedvectors.Vocab at 0x2208e495eb8>,
#  'الحسان': <gensim.models.keyedvectors.Vocab at 0x2208e644898>,
#  'خریدن': <gensim.models.keyedvectors.Vocab at 0x2208e4ff438>,
#  'پرشمار': <gensim.models.keyedvectors.Vocab at 0x2208e418160>,
#  'تعصبات': <gensim.models.keyedvectors.Vocab at 0x2208e46b470>,
#  'طفل': <gensim.models.keyedvectors.Vocab at 0x2208e544ba8>,
#  'وافر': <gensim.models.keyedvectors.Vocab at 0x2208e3c12b0>,
#  'عدول': <gensim.models.keyedvectors.Vocab at 0x2208e6a32e8>,
#  'خیالی': <gensim.models.keyedvectors.Vocab at 0x2208e4c2cc0>,
#  'ریکاوری': <gensim.models.keyedvectors.Vocab at 0x2208e40d518>,
#  'یکوقت': <gensim.models.keyedvectors.Vocab at 0x2208e4dfba8>,
#  'جَمیعَ': <gensim.models.keyedvectors.Vocab at 0x2208e6a9160>,
#  'نکشند': <gensim.models.keyedvectors.Vocab at 0x2208e3337f0>,
#  'بندها': <gensim.models.keyedvectors.Vocab at 0x2208e490c50>,
#  'جنگافزارهای': <gensim.models.keyedvectors.Vocab at 0x2208e6819b0>,
#  'اوتاراکاند': <gensim.models.keyedvectors.Vocab at 0x2208e495860>,
#  'کارلو': <gensim.models.keyedvectors.Vocab at 0x2208e58f6d8>,
#  'نوازی': <gensim.models.keyedvectors.Vocab at 0x2208e6da208>,
#  'پیاستر': <gensim.models.keyedvectors.Vocab at 0x2208e57bc50>,
#  'جهانی': <gensim.models.keyedvectors.Vocab at 0x2208dd22320>,
#  'کالیفرنیا': <gensim.models.keyedvectors.Vocab at 0x2208e664d68>,
#  'موفاز': <gensim.models.keyedvectors.Vocab at 0x2208e6e8940>,
#  'صحرای': <gensim.models.keyedvectors.Vocab at 0x2208e5c8c88>,
#  'ششم': <gensim.models.keyedvectors.Vocab at 0x2208e4aefd0>,
#  'اختلاف': <gensim.models.keyedvectors.Vocab at 0x2208e396e80>,
#  'استانداردهای': <gensim.models.keyedvectors.Vocab at 0x2208e46bc50>,
#  'وزارتخارجه': <gensim.models.keyedvectors.Vocab at 0x2208e687c88>,
#  'نایروبی': <gensim.models.keyedvectors.Vocab at 0x2208e4ff630>,
#  'شِکوه': <gensim.models.keyedvectors.Vocab at 0x2208e512748>,
#  'گسیل': <gensim.models.keyedvectors.Vocab at 0x2208e5b5898>,
#  'استوار': <gensim.models.keyedvectors.Vocab at 0x2208e31a2e8>,
#  'فکری': <gensim.models.keyedvectors.Vocab at 0x2208e3c9240>,
#  'رفاقت': <gensim.models.keyedvectors.Vocab at 0x2208e65de48>,
#  'نمازگزاران': <gensim.models.keyedvectors.Vocab at 0x2208e618400>,
#  'قربانیان': <gensim.models.keyedvectors.Vocab at 0x2208e3cffd0>,
#  'هاشمیان': <gensim.models.keyedvectors.Vocab at 0x2208e40ddd8>,
#  'تهمتهایی': <gensim.models.keyedvectors.Vocab at 0x2208e52b710>,
#  'بینیم': <gensim.models.keyedvectors.Vocab at 0x2208e400be0>,
#  'دموکراسی': <gensim.models.keyedvectors.Vocab at 0x2208e3150f0>,
#  'بحمد': <gensim.models.keyedvectors.Vocab at 0x2208e3dab00>,
#  'نیستی': <gensim.models.keyedvectors.Vocab at 0x2208e52b748>,
#  'استون': <gensim.models.keyedvectors.Vocab at 0x2208e4004e0>,
#  'له': <gensim.models.keyedvectors.Vocab at 0x2208e3082b0>,
#  'موقعیت': <gensim.models.keyedvectors.Vocab at 0x2208e2fb240>,
#  'جانم': <gensim.models.keyedvectors.Vocab at 0x2208e6af3c8>,
#  'منات': <gensim.models.keyedvectors.Vocab at 0x2208e5af128>,
#  'سوچی': <gensim.models.keyedvectors.Vocab at 0x2208e4f3630>,
#  'مرزی': <gensim.models.keyedvectors.Vocab at 0x2208e418ef0>,
#  'راشد': <gensim.models.keyedvectors.Vocab at 0x2208e59cc18>,
#  'خمیر': <gensim.models.keyedvectors.Vocab at 0x2208e39c710>,
#  'رعایت': <gensim.models.keyedvectors.Vocab at 0x2208e2d7b00>,
#  'میشمارد': <gensim.models.keyedvectors.Vocab at 0x2208e6442e8>,
#  'نظارتى': <gensim.models.keyedvectors.Vocab at 0x2208e6111d0>,
#  'منشا': <gensim.models.keyedvectors.Vocab at 0x2208e32e860>,
#  'شخص': <gensim.models.keyedvectors.Vocab at 0x2208e3157f0>,
#  'ریختن': <gensim.models.keyedvectors.Vocab at 0x2208e47df60>,
#  'پرندلی': <gensim.models.keyedvectors.Vocab at 0x2208e6e8cc0>,
#  'تحلیلگر': <gensim.models.keyedvectors.Vocab at 0x2208e470fd0>,
#  'چادر': <gensim.models.keyedvectors.Vocab at 0x2208e5cda58>,
#  'معاشرت': <gensim.models.keyedvectors.Vocab at 0x2208e6360b8>,
#  'ارزشی': <gensim.models.keyedvectors.Vocab at 0x2208e400f60>,
#  'شدکه': <gensim.models.keyedvectors.Vocab at 0x2208e611978>,
#  'منتظر': <gensim.models.keyedvectors.Vocab at 0x2208e2aad30>,
#  'شركت': <gensim.models.keyedvectors.Vocab at 0x2208e687470>,
#  'زهکشی': <gensim.models.keyedvectors.Vocab at 0x2208e2d1fd0>,
#  'تنفر': <gensim.models.keyedvectors.Vocab at 0x2208e46b898>,
#  'شنود': <gensim.models.keyedvectors.Vocab at 0x2208e67c080>,
#  'نقدر': <gensim.models.keyedvectors.Vocab at 0x2208e3335c0>,
#  'چهارماه': <gensim.models.keyedvectors.Vocab at 0x2208e6b57f0>,
#  'انسولین': <gensim.models.keyedvectors.Vocab at 0x2208e3a9a90>,
#  'زیست': <gensim.models.keyedvectors.Vocab at 0x2208dd5f438>,
#  'راهب': <gensim.models.keyedvectors.Vocab at 0x2208e4f32b0>,
#  'روانشناس': <gensim.models.keyedvectors.Vocab at 0x2208e636a58>,
#  'نهاست': <gensim.models.keyedvectors.Vocab at 0x2208e426c18>,
#  'متزلزل': <gensim.models.keyedvectors.Vocab at 0x2208e3fa588>,
#  'حمل': <gensim.models.keyedvectors.Vocab at 0x2208e64aa20>,
#  'زیستن': <gensim.models.keyedvectors.Vocab at 0x2208e4065c0>,
#  'گویندۀ': <gensim.models.keyedvectors.Vocab at 0x2208e512fd0>,
#  'فراهنگ': <gensim.models.keyedvectors.Vocab at 0x2208e6e8588>,
#  'مخربی': <gensim.models.keyedvectors.Vocab at 0x2208e41dba8>,
#  'مهرایی': <gensim.models.keyedvectors.Vocab at 0x2208e6259e8>,
#  'شوق': <gensim.models.keyedvectors.Vocab at 0x2208e42b780>,
#  'شارژ': <gensim.models.keyedvectors.Vocab at 0x2208e6bb2e8>,
#  'مشکلاتش': <gensim.models.keyedvectors.Vocab at 0x2208e59cba8>,
#  'وفای': <gensim.models.keyedvectors.Vocab at 0x2208e6316a0>,
#  'بیافتد': <gensim.models.keyedvectors.Vocab at 0x2208e650da0>,
#  'سنگین': <gensim.models.keyedvectors.Vocab at 0x2208e2bd080>,
#  'سارین': <gensim.models.keyedvectors.Vocab at 0x2208e3ec2e8>,
#  'مارکس': <gensim.models.keyedvectors.Vocab at 0x2208e68e978>,
#  'توانشان': <gensim.models.keyedvectors.Vocab at 0x2208e6700b8>,
#  'اشکور': <gensim.models.keyedvectors.Vocab at 0x2208e35f710>,
#  'نفع': <gensim.models.keyedvectors.Vocab at 0x2208e315f60>,
#  'بیزینس': <gensim.models.keyedvectors.Vocab at 0x2208e6cd0f0>,
#  'اخیرا': <gensim.models.keyedvectors.Vocab at 0x2208e3c10f0>,
#  'پرورش': <gensim.models.keyedvectors.Vocab at 0x2208e377a90>,
#  'دادخواهی': <gensim.models.keyedvectors.Vocab at 0x2208e4c8a58>,
#  'تدبیری': <gensim.models.keyedvectors.Vocab at 0x2208e326278>,
#  'سامول': <gensim.models.keyedvectors.Vocab at 0x2208e668400>,
#  'دستهایش': <gensim.models.keyedvectors.Vocab at 0x2208e544c88>,
#  'سحر': <gensim.models.keyedvectors.Vocab at 0x2208e55c128>,
#  'رنگارنگ': <gensim.models.keyedvectors.Vocab at 0x2208e69d518>,
#  'مثر': <gensim.models.keyedvectors.Vocab at 0x2208e308e10>,
#  'بالادستی': <gensim.models.keyedvectors.Vocab at 0x2208e4908d0>,
#  'کشیش': <gensim.models.keyedvectors.Vocab at 0x2208e581908>,
#  'پرستی': <gensim.models.keyedvectors.Vocab at 0x2208e53eeb8>,
#  'دوّمی': <gensim.models.keyedvectors.Vocab at 0x2208e4f9cf8>,
#  'فرزند': <gensim.models.keyedvectors.Vocab at 0x2208e3e80b8>,
#  'عوارض': <gensim.models.keyedvectors.Vocab at 0x2208e3967b8>,
#  'یَرَهُ': <gensim.models.keyedvectors.Vocab at 0x2208e6314a8>,
#  'خطرناک': <gensim.models.keyedvectors.Vocab at 0x2208e3af668>,
#  'خوشحالی': <gensim.models.keyedvectors.Vocab at 0x2208e3159e8>,
#  'شاملو': <gensim.models.keyedvectors.Vocab at 0x2208e5766a0>,
#  'جماهیر': <gensim.models.keyedvectors.Vocab at 0x2208e5960b8>,
#  'مادرم': <gensim.models.keyedvectors.Vocab at 0x2208e544d68>,
#  'خوشبختی': <gensim.models.keyedvectors.Vocab at 0x2208e4f9e10>,
#  '٬': <gensim.models.keyedvectors.Vocab at 0x2208e60bd30>,
#  'نرخ': <gensim.models.keyedvectors.Vocab at 0x2208dd22b70>,
#  'البغدادی': <gensim.models.keyedvectors.Vocab at 0x2208e6e8630>,
#  'بچههای': <gensim.models.keyedvectors.Vocab at 0x2208e4a9390>,
#  'چرام': <gensim.models.keyedvectors.Vocab at 0x2208e2bdeb8>,
#  'دریاچه': <gensim.models.keyedvectors.Vocab at 0x2208e365908>,
#  'شهنازها': <gensim.models.keyedvectors.Vocab at 0x2208e63d208>,
#  'خوزه': <gensim.models.keyedvectors.Vocab at 0x2208e6e8be0>,
#  'بودجه': <gensim.models.keyedvectors.Vocab at 0x2208e2dd828>,
#  'سوزی': <gensim.models.keyedvectors.Vocab at 0x2208e4c25c0>,
#  'هانس': <gensim.models.keyedvectors.Vocab at 0x2208e530c88>,
#  'ریاضتی': <gensim.models.keyedvectors.Vocab at 0x2208e5af2e8>,
#  'سندیکایی': <gensim.models.keyedvectors.Vocab at 0x2208e6b59e8>,
#  'بِجَزیلِ': <gensim.models.keyedvectors.Vocab at 0x2208e6af400>,
#  'باغشاه': <gensim.models.keyedvectors.Vocab at 0x2208e64aa90>,
#  'زمون': <gensim.models.keyedvectors.Vocab at 0x2208e39c898>,
#  'دیدار': <gensim.models.keyedvectors.Vocab at 0x2208e2dd0b8>,
#  'دقیقی': <gensim.models.keyedvectors.Vocab at 0x2208e557240>,
#  'مذاکراتش': <gensim.models.keyedvectors.Vocab at 0x2208e2ead30>,
#  'رهنورد': <gensim.models.keyedvectors.Vocab at 0x2208e4ae358>,
#  'نمک': <gensim.models.keyedvectors.Vocab at 0x2208e3960f0>,
#  'کشوری': <gensim.models.keyedvectors.Vocab at 0x2208e33f908>,
#  'معنادار': <gensim.models.keyedvectors.Vocab at 0x2208e5db6a0>,
#  'طیرانیان': <gensim.models.keyedvectors.Vocab at 0x2208e3211d0>,
#  'دیسیپلین': <gensim.models.keyedvectors.Vocab at 0x2208e5f27f0>,
#  'سازوکاری': <gensim.models.keyedvectors.Vocab at 0x2208e4c8eb8>,
#  'غنایم': <gensim.models.keyedvectors.Vocab at 0x2208e681b00>,
#  'روسی': <gensim.models.keyedvectors.Vocab at 0x2208e3e2a58>,
#  'حدّ': <gensim.models.keyedvectors.Vocab at 0x2208e4f9d30>,
#  'وینچی': <gensim.models.keyedvectors.Vocab at 0x2208e4e6550>,
#  'شوهانی': <gensim.models.keyedvectors.Vocab at 0x2208e668be0>,
#  'تقریب': <gensim.models.keyedvectors.Vocab at 0x2208e5d4908>,
#  'معاش': <gensim.models.keyedvectors.Vocab at 0x2208e4587f0>,
#  'رسیدهاند': <gensim.models.keyedvectors.Vocab at 0x2208e600240>,
#  'خریداران': <gensim.models.keyedvectors.Vocab at 0x2208e4a22b0>,
#  'ملاقات': <gensim.models.keyedvectors.Vocab at 0x2208e33fb00>,
#  'شهریور': <gensim.models.keyedvectors.Vocab at 0x2208dd28cf8>,
#  'کنیه': <gensim.models.keyedvectors.Vocab at 0x2208e6e84a8>,
#  'جیرانی': <gensim.models.keyedvectors.Vocab at 0x2208e3facf8>,
#  'ساسان': <gensim.models.keyedvectors.Vocab at 0x2208e384320>,
#  'احاطه': <gensim.models.keyedvectors.Vocab at 0x2208e5b5470>,
#  'حاصلش': <gensim.models.keyedvectors.Vocab at 0x2208e482240>,
#  'نودا': <gensim.models.keyedvectors.Vocab at 0x2208e5b59e8>,
#  'برکات': <gensim.models.keyedvectors.Vocab at 0x2208e37ceb8>,
#  'خیزش': <gensim.models.keyedvectors.Vocab at 0x2208e3bc390>,
#  'رفع': <gensim.models.keyedvectors.Vocab at 0x2208e2cb668>,
#  'تظاهرکننده': <gensim.models.keyedvectors.Vocab at 0x2208e2e2940>,
#  'ناحیه': <gensim.models.keyedvectors.Vocab at 0x2208e31a908>,
#  'اکرم': <gensim.models.keyedvectors.Vocab at 0x2208e431ac8>,
#  'فصلی': <gensim.models.keyedvectors.Vocab at 0x2208e365358>,
#  'ورزشکاری': <gensim.models.keyedvectors.Vocab at 0x2208e6d52b0>,
#  'بناها': <gensim.models.keyedvectors.Vocab at 0x2208e4bb0b8>,
#  'کلانی': <gensim.models.keyedvectors.Vocab at 0x2208e308940>,
#  'ملّت': <gensim.models.keyedvectors.Vocab at 0x2208e506860>,
#  'مدرنیته': <gensim.models.keyedvectors.Vocab at 0x2208e5f2400>,
#  'نسلی': <gensim.models.keyedvectors.Vocab at 0x2208e413080>,
#  'درستکار': <gensim.models.keyedvectors.Vocab at 0x2208e4000b8>,
#  'تست': <gensim.models.keyedvectors.Vocab at 0x2208e2efe80>,
#  'عاجل': <gensim.models.keyedvectors.Vocab at 0x2208e4d49b0>,
#  'همسو': <gensim.models.keyedvectors.Vocab at 0x2208e3155c0>,
#  'ثروتمندان': <gensim.models.keyedvectors.Vocab at 0x2208e68e5f8>,
#  'شمی': <gensim.models.keyedvectors.Vocab at 0x2208e6873c8>,
#  'فدا': <gensim.models.keyedvectors.Vocab at 0x2208e42b550>,
#  'الموجودین': <gensim.models.keyedvectors.Vocab at 0x2208e60b438>,
#  'شرکتها': <gensim.models.keyedvectors.Vocab at 0x2208e495048>,
#  'یت_الله': <gensim.models.keyedvectors.Vocab at 0x2208e2a5e48>,
#  'راهنمای': <gensim.models.keyedvectors.Vocab at 0x2208e3da860>,
#  'طوسیوُلتر': <gensim.models.keyedvectors.Vocab at 0x2208e5305c0>,
#  'کروش': <gensim.models.keyedvectors.Vocab at 0x2208e3fa358>,
#  'مجرم': <gensim.models.keyedvectors.Vocab at 0x2208e2a55f8>,
#  'ینده': <gensim.models.keyedvectors.Vocab at 0x2208dd224a8>,
#  'جوادالامه': <gensim.models.keyedvectors.Vocab at 0x2208e67c4e0>,
#  'کارت': <gensim.models.keyedvectors.Vocab at 0x2208e2f6b70>,
#  'فتا': <gensim.models.keyedvectors.Vocab at 0x2208e69df60>,
#  'منطبق': <gensim.models.keyedvectors.Vocab at 0x2208dd53a20>,
#  'شوب': <gensim.models.keyedvectors.Vocab at 0x2208e475f60>,
#  'مجازی': <gensim.models.keyedvectors.Vocab at 0x2208dd3f780>,
#  'وبخشودگی': <gensim.models.keyedvectors.Vocab at 0x2208e6da908>,
#  'خدمتش': <gensim.models.keyedvectors.Vocab at 0x2208e5ee0f0>,
#  'نزل': <gensim.models.keyedvectors.Vocab at 0x2208e62a208>,
#  'طلاق': <gensim.models.keyedvectors.Vocab at 0x2208e2bdbe0>,
#  'فرامین': <gensim.models.keyedvectors.Vocab at 0x2208e406e48>,
#  'متوفی': <gensim.models.keyedvectors.Vocab at 0x2208e4cec88>,
#  'خبر': <gensim.models.keyedvectors.Vocab at 0x2208dd2d898>,
#  'بینایی': <gensim.models.keyedvectors.Vocab at 0x2208e69dbe0>,
#  'خراسان': <gensim.models.keyedvectors.Vocab at 0x2208e2bd898>,
#  'جدای': <gensim.models.keyedvectors.Vocab at 0x2208e396fd0>,
#  'سیاستگذاریهای': <gensim.models.keyedvectors.Vocab at 0x2208e44abe0>,
#  'امروزمان': <gensim.models.keyedvectors.Vocab at 0x2208e406e80>,
#  'برپای': <gensim.models.keyedvectors.Vocab at 0x2208e687c18>,
#  'ثاری': <gensim.models.keyedvectors.Vocab at 0x2208e357630>,
#  'عاملیت': <gensim.models.keyedvectors.Vocab at 0x2208e3bc7b8>,
#  'بردگی': <gensim.models.keyedvectors.Vocab at 0x2208e5501d0>,
#  'نوموزان': <gensim.models.keyedvectors.Vocab at 0x2208e69dba8>,
#  'بررسى': <gensim.models.keyedvectors.Vocab at 0x2208e644668>,
#  'شایانی': <gensim.models.keyedvectors.Vocab at 0x2208e60b630>,
#  'الحِسان': <gensim.models.keyedvectors.Vocab at 0x2208e644908>,
#  'برخط': <gensim.models.keyedvectors.Vocab at 0x2208e625438>,
#  'وحشیانه': <gensim.models.keyedvectors.Vocab at 0x2208e49b710>,
#  'سوادی': <gensim.models.keyedvectors.Vocab at 0x2208e3b6be0>,
#  'سلاحها': <gensim.models.keyedvectors.Vocab at 0x2208e495f28>,
#  'موزهها': <gensim.models.keyedvectors.Vocab at 0x2208e620a20>,
#  'ناهنجاری': <gensim.models.keyedvectors.Vocab at 0x2208e6daa90>,
#  'فقدان': <gensim.models.keyedvectors.Vocab at 0x2208e475748>,
#  'زحل': <gensim.models.keyedvectors.Vocab at 0x2208e3e88d0>,
#  'شاهرخ': <gensim.models.keyedvectors.Vocab at 0x2208e41d6a0>,
#  'مصلحتگرایی': <gensim.models.keyedvectors.Vocab at 0x2208e4753c8>,
#  'زید': <gensim.models.keyedvectors.Vocab at 0x2208e36b048>,
#  'طبق': <gensim.models.keyedvectors.Vocab at 0x2208e2f6a58>,
#  'ترویج': <gensim.models.keyedvectors.Vocab at 0x2208e3cfe48>,
#  'فیلسوفها': <gensim.models.keyedvectors.Vocab at 0x2208e536fd0>,
#  'هزینهی': <gensim.models.keyedvectors.Vocab at 0x2208e681dd8>,
#  'ایفا': <gensim.models.keyedvectors.Vocab at 0x2208e2d7320>,
#  'عبدالناصر': <gensim.models.keyedvectors.Vocab at 0x2208e57ba58>,
#  'مولانا': <gensim.models.keyedvectors.Vocab at 0x2208e5ee2e8>,
#  'اینفو': <gensim.models.keyedvectors.Vocab at 0x2208e596550>,
#  'امیرمحمد': <gensim.models.keyedvectors.Vocab at 0x2208e64a588>,
#  'مهدی_عج': <gensim.models.keyedvectors.Vocab at 0x2208e42b4e0>,
#  'زدم': <gensim.models.keyedvectors.Vocab at 0x2208e4ee7b8>,
#  'تذکر': <gensim.models.keyedvectors.Vocab at 0x2208e413ac8>,
#  'خزعلی': <gensim.models.keyedvectors.Vocab at 0x2208e6da390>,
#  'توافقنامه': <gensim.models.keyedvectors.Vocab at 0x2208e5c2ac8>,
#  'لوایح': <gensim.models.keyedvectors.Vocab at 0x2208e308f28>,
#  'جم': <gensim.models.keyedvectors.Vocab at 0x2208e3702e8>,
#  'تحریر': <gensim.models.keyedvectors.Vocab at 0x2208e46bf28>,
#  'مولف': <gensim.models.keyedvectors.Vocab at 0x2208e3bc630>,
#  'لفظی': <gensim.models.keyedvectors.Vocab at 0x2208e5302b0>,
#  'محتاج': <gensim.models.keyedvectors.Vocab at 0x2208e512390>,
#  'سادۀ': <gensim.models.keyedvectors.Vocab at 0x2208e4d9d30>,
#  'افشاگری': <gensim.models.keyedvectors.Vocab at 0x2208e681438>,
#  'کاشی': <gensim.models.keyedvectors.Vocab at 0x2208e664b38>,
#  'ابوالقاسم': <gensim.models.keyedvectors.Vocab at 0x2208e5ee240>,
#  'زیارت': <gensim.models.keyedvectors.Vocab at 0x2208e3578d0>,
#  'برمده': <gensim.models.keyedvectors.Vocab at 0x2208e3e8550>,
#  'تفریغ': <gensim.models.keyedvectors.Vocab at 0x2208e495630>,
#  'صادرکنندگان': <gensim.models.keyedvectors.Vocab at 0x2208e345400>,
#  'دادرسی': <gensim.models.keyedvectors.Vocab at 0x2208e301748>,
#  'عدلیه': <gensim.models.keyedvectors.Vocab at 0x2208e56a828>,
#  'مراجعان': <gensim.models.keyedvectors.Vocab at 0x2208e620b38>,
#  'میلون': <gensim.models.keyedvectors.Vocab at 0x2208e57b160>,
#  'حافظۀ': <gensim.models.keyedvectors.Vocab at 0x2208e570630>,
#  'مسولی': <gensim.models.keyedvectors.Vocab at 0x2208e315d30>,
#  'نزولات': <gensim.models.keyedvectors.Vocab at 0x2208e41da20>,
#  'جشنوارههای': <gensim.models.keyedvectors.Vocab at 0x2208e44af28>,
#  'دیرباز': <gensim.models.keyedvectors.Vocab at 0x2208e35f898>,
#  'بریند': <gensim.models.keyedvectors.Vocab at 0x2208e650d68>,
#  'فست': <gensim.models.keyedvectors.Vocab at 0x2208e3907b8>,
#  'شرط': <gensim.models.keyedvectors.Vocab at 0x2208e400978>,
#  'کمک': <gensim.models.keyedvectors.Vocab at 0x2208dd2d6a0>,
#  'مقام_معظم': <gensim.models.keyedvectors.Vocab at 0x2208dd5fb38>,
#  'باب': <gensim.models.keyedvectors.Vocab at 0x2208e357d68>,
#  'سیاستها': <gensim.models.keyedvectors.Vocab at 0x2208e4d4b70>,
#  'رسیدیم': <gensim.models.keyedvectors.Vocab at 0x2208e33f5c0>,
#  'خانوارها': <gensim.models.keyedvectors.Vocab at 0x2208e6703c8>,
#  'کوچکترین': <gensim.models.keyedvectors.Vocab at 0x2208e37c6a0>,
#  'روستا': <gensim.models.keyedvectors.Vocab at 0x2208e2bdfd0>,
#  'اصول': <gensim.models.keyedvectors.Vocab at 0x2208dd4c2b0>,
#  'امتیازات': <gensim.models.keyedvectors.Vocab at 0x2208e413550>,
#  'اقدامی': <gensim.models.keyedvectors.Vocab at 0x2208e31aa58>,
#  'سمانی': <gensim.models.keyedvectors.Vocab at 0x2208e41da58>,
#  'اتوبوسی': <gensim.models.keyedvectors.Vocab at 0x2208e530ef0>,
#  'ازبکستان': <gensim.models.keyedvectors.Vocab at 0x2208e4b42e8>,
#  'جذاب': <gensim.models.keyedvectors.Vocab at 0x2208e2ef4e0>,
#  'مدونی': <gensim.models.keyedvectors.Vocab at 0x2208e3bcda0>,
#  'ترساند': <gensim.models.keyedvectors.Vocab at 0x2208e544dd8>,
#  'رحمانی': <gensim.models.keyedvectors.Vocab at 0x2208e6765c0>,
#  'تیشه': <gensim.models.keyedvectors.Vocab at 0x2208e67c8d0>,
#  'مهاجرانی': <gensim.models.keyedvectors.Vocab at 0x2208e32ec50>,
#  'اشکرافت': <gensim.models.keyedvectors.Vocab at 0x2208e6bbc50>,
#  'ژانویه': <gensim.models.keyedvectors.Vocab at 0x2208e596b38>,
#  'بیاموزند': <gensim.models.keyedvectors.Vocab at 0x2208e3c12e8>,
#  'تفاهمی': <gensim.models.keyedvectors.Vocab at 0x2208e6252e8>,
#  'تبعیضهای': <gensim.models.keyedvectors.Vocab at 0x2208e5d4dd8>,
#  'مبنای': <gensim.models.keyedvectors.Vocab at 0x2208e2ddda0>,
#  'جلوگيری': <gensim.models.keyedvectors.Vocab at 0x2208e6bbf60>,
#  'ترجمه': <gensim.models.keyedvectors.Vocab at 0x2208e4469e8>,
#  'اندر': <gensim.models.keyedvectors.Vocab at 0x2208e576828>,
#  'مجذوب': <gensim.models.keyedvectors.Vocab at 0x2208e611f60>,
#  'چراکه': <gensim.models.keyedvectors.Vocab at 0x2208e301a58>,
#  'بیان': <gensim.models.keyedvectors.Vocab at 0x2208e2aa550>,
#  'همدانی': <gensim.models.keyedvectors.Vocab at 0x2208e37cc88>,
#  'فروزان': <gensim.models.keyedvectors.Vocab at 0x2208e620ac8>,
#  'ارشاد_اسلامی': <gensim.models.keyedvectors.Vocab at 0x2208e446c88>,
#  'خورد': <gensim.models.keyedvectors.Vocab at 0x2208dd28080>,
#  'اتصال': <gensim.models.keyedvectors.Vocab at 0x2208dd3aa58>,
#  'ساویتسکایا': <gensim.models.keyedvectors.Vocab at 0x2208e3e81d0>,
#  'عبادت': <gensim.models.keyedvectors.Vocab at 0x2208e2aab70>,
#  'زیرساختی': <gensim.models.keyedvectors.Vocab at 0x2208e611d68>,
#  '١٣٨٤': <gensim.models.keyedvectors.Vocab at 0x2208e4ce438>,
#  'پردازد': <gensim.models.keyedvectors.Vocab at 0x2208e3d4da0>,
#  'کشورم': <gensim.models.keyedvectors.Vocab at 0x2208e5dfd68>,
#  'مسافرین': <gensim.models.keyedvectors.Vocab at 0x2208e618a90>,
#  'اولیک': <gensim.models.keyedvectors.Vocab at 0x2208e345fd0>,
#  'بشری': <gensim.models.keyedvectors.Vocab at 0x2208e40dd30>,
#  'تراکتورسازی': <gensim.models.keyedvectors.Vocab at 0x2208e5df5f8>,
#  'نسیم': <gensim.models.keyedvectors.Vocab at 0x2208e437438>,
#  'افسر': <gensim.models.keyedvectors.Vocab at 0x2208e5bb2e8>,
#  'ذرماه': <gensim.models.keyedvectors.Vocab at 0x2208e2b68d0>,
#  'انگلیسی': <gensim.models.keyedvectors.Vocab at 0x2208dd537b8>,
#  'سَوْتِهِما': <gensim.models.keyedvectors.Vocab at 0x2208e636b00>,
#  'غربیها': <gensim.models.keyedvectors.Vocab at 0x2208e56a080>,
#  'اعصاب': <gensim.models.keyedvectors.Vocab at 0x2208e3da198>,
#  'پذیرفتن': <gensim.models.keyedvectors.Vocab at 0x2208e5af710>,
#  'گذاشتم': <gensim.models.keyedvectors.Vocab at 0x2208e3e8cc0>,
#  'امیر': <gensim.models.keyedvectors.Vocab at 0x2208e2eadd8>,
#  'مظاهری': <gensim.models.keyedvectors.Vocab at 0x2208e644390>,
#  'برگزیدن': <gensim.models.keyedvectors.Vocab at 0x2208e5db160>,
#  'دعواها': <gensim.models.keyedvectors.Vocab at 0x2208e3cfbe0>,
#  'عوالم': <gensim.models.keyedvectors.Vocab at 0x2208e5f2780>,
#  'تقلب': <gensim.models.keyedvectors.Vocab at 0x2208e4c8c88>,
#  'بپردازیم': <gensim.models.keyedvectors.Vocab at 0x2208e46b048>,
#  'غافلگیرانه': <gensim.models.keyedvectors.Vocab at 0x2208e668780>,
#  'شایان': <gensim.models.keyedvectors.Vocab at 0x2208e5a36d8>,
#  'مرزبندی': <gensim.models.keyedvectors.Vocab at 0x2208e60be80>,
#  'مشترک': <gensim.models.keyedvectors.Vocab at 0x2208e377048>,
#  'حلهایی': <gensim.models.keyedvectors.Vocab at 0x2208e5c2eb8>,
#  'فرستاده': <gensim.models.keyedvectors.Vocab at 0x2208e301d30>,
#  'ترابی': <gensim.models.keyedvectors.Vocab at 0x2208e44a8d0>,
#  'سوشیتد': <gensim.models.keyedvectors.Vocab at 0x2208e4ae748>,
#  'زاد': <gensim.models.keyedvectors.Vocab at 0x2208dd2dda0>,
#  'علیاشرف': <gensim.models.keyedvectors.Vocab at 0x2208e45c588>,
#  'عجیبی': <gensim.models.keyedvectors.Vocab at 0x2208e3e2eb8>,
#  'تهییج': <gensim.models.keyedvectors.Vocab at 0x2208e636d68>,
#  'رخت': <gensim.models.keyedvectors.Vocab at 0x2208e618f28>,
#  'ماهوری': <gensim.models.keyedvectors.Vocab at 0x2208e41d400>,
#  'مرحوم': <gensim.models.keyedvectors.Vocab at 0x2208e400cc0>,
#  'نوازند': <gensim.models.keyedvectors.Vocab at 0x2208e5762e8>,
#  'پوششی': <gensim.models.keyedvectors.Vocab at 0x2208e636048>,
#  'افتاد': <gensim.models.keyedvectors.Vocab at 0x2208e3da6d8>,
#  'قانونگذاری': <gensim.models.keyedvectors.Vocab at 0x2208e5a3b00>,
#  'محصولی': <gensim.models.keyedvectors.Vocab at 0x2208e2f6668>,
#  'پسته': <gensim.models.keyedvectors.Vocab at 0x2208e6200b8>,
#  'ورزش_جوانان': <gensim.models.keyedvectors.Vocab at 0x2208e2ef240>,
#  'برجای': <gensim.models.keyedvectors.Vocab at 0x2208e3e2e48>,
#  'مروری': <gensim.models.keyedvectors.Vocab at 0x2208e3e2748>,
#  'چاقوهای': <gensim.models.keyedvectors.Vocab at 0x2208e56a9b0>,
#  'کارزار': <gensim.models.keyedvectors.Vocab at 0x2208e589ac8>,
#  'اصلح': <gensim.models.keyedvectors.Vocab at 0x2208e4136a0>,
#  'مشی': <gensim.models.keyedvectors.Vocab at 0x2208e326518>,
#  'معبودى': <gensim.models.keyedvectors.Vocab at 0x2208e6a9cf8>,
#  'شکارچیان': <gensim.models.keyedvectors.Vocab at 0x2208e41d748>,
#  'شوری': <gensim.models.keyedvectors.Vocab at 0x2208e365828>,
#  'ایده': <gensim.models.keyedvectors.Vocab at 0x2208e31ae10>,
#  'انسان': <gensim.models.keyedvectors.Vocab at 0x2208e2aa860>,
#  'ارسالی': <gensim.models.keyedvectors.Vocab at 0x2208e30f320>,
#  'مسلح': <gensim.models.keyedvectors.Vocab at 0x2208e30fbe0>,
#  'گشایش_دفتر': <gensim.models.keyedvectors.Vocab at 0x2208e3cf940>,
#  'مداخلات': <gensim.models.keyedvectors.Vocab at 0x2208e6c8588>,
#  'باغهای': <gensim.models.keyedvectors.Vocab at 0x2208e36b400>,
#  'زین': <gensim.models.keyedvectors.Vocab at 0x2208e357f98>,
#  'شتاب': <gensim.models.keyedvectors.Vocab at 0x2208e33fd68>,
#  'میدارد': <gensim.models.keyedvectors.Vocab at 0x2208e644320>,
#  'مرمت': <gensim.models.keyedvectors.Vocab at 0x2208e600b00>,
#  'میمون': <gensim.models.keyedvectors.Vocab at 0x2208e47dc88>,
#  'بستۀ': <gensim.models.keyedvectors.Vocab at 0x2208e50a4e0>,
#  'بانی': <gensim.models.keyedvectors.Vocab at 0x2208e41d940>,
#  'اشغال': <gensim.models.keyedvectors.Vocab at 0x2208e4c83c8>,
#  'یحیی': <gensim.models.keyedvectors.Vocab at 0x2208e470240>,
#  'ساکن': <gensim.models.keyedvectors.Vocab at 0x2208e33afd0>,
#  'احراز': <gensim.models.keyedvectors.Vocab at 0x2208e2b6278>,
#  'رباعی': <gensim.models.keyedvectors.Vocab at 0x2208e557390>,
#  'کوبیدند': <gensim.models.keyedvectors.Vocab at 0x2208e694c88>,
#  'رعنا': <gensim.models.keyedvectors.Vocab at 0x2208e4c2710>,
#  'کرمانی': <gensim.models.keyedvectors.Vocab at 0x2208e3c9e48>,
#  'شکستش': <gensim.models.keyedvectors.Vocab at 0x2208e413128>,
#  'تهی': <gensim.models.keyedvectors.Vocab at 0x2208e357eb8>,
#  'سیمای': <gensim.models.keyedvectors.Vocab at 0x2208e426630>,
#  'مقدسی': <gensim.models.keyedvectors.Vocab at 0x2208e631160>,
#  'ایثارگر': <gensim.models.keyedvectors.Vocab at 0x2208e600940>,
#  'مجوزی': <gensim.models.keyedvectors.Vocab at 0x2208e6c86d8>,
#  'ایمانی': <gensim.models.keyedvectors.Vocab at 0x2208e3f3d30>,
#  'کالری': <gensim.models.keyedvectors.Vocab at 0x2208e345e10>,
#  'الَّذِینَ': <gensim.models.keyedvectors.Vocab at 0x2208e6315c0>,
#  'کوچکش': <gensim.models.keyedvectors.Vocab at 0x2208e4ff390>,
#  'تکه': <gensim.models.keyedvectors.Vocab at 0x2208e600780>,
#  'نزند': <gensim.models.keyedvectors.Vocab at 0x2208e3e8438>,
#  'تشریح': <gensim.models.keyedvectors.Vocab at 0x2208e2b1128>,
#  'شگرفی': <gensim.models.keyedvectors.Vocab at 0x2208e68ea58>,
#  'مریم': <gensim.models.keyedvectors.Vocab at 0x2208e426e80>,
#  'ردیف': <gensim.models.keyedvectors.Vocab at 0x2208e315588>,
#  'ترافیکی': <gensim.models.keyedvectors.Vocab at 0x2208e625470>,
#  'استعفای': <gensim.models.keyedvectors.Vocab at 0x2208e3d4390>,
#  'سرلشگر': <gensim.models.keyedvectors.Vocab at 0x2208e3e24e0>,
#  'تجسس': <gensim.models.keyedvectors.Vocab at 0x2208e5a7a20>,
#  'غبار': <gensim.models.keyedvectors.Vocab at 0x2208e4bbac8>,
#  'وهمکاری': <gensim.models.keyedvectors.Vocab at 0x2208e6da048>,
#  'بازگو': <gensim.models.keyedvectors.Vocab at 0x2208e5cdb00>,
#  'فراری': <gensim.models.keyedvectors.Vocab at 0x2208e301f28>,
#  'انحطاط': <gensim.models.keyedvectors.Vocab at 0x2208e452048>,
#  'جذب': <gensim.models.keyedvectors.Vocab at 0x2208e2bd278>,
#  'سملقان': <gensim.models.keyedvectors.Vocab at 0x2208e67c438>,
#  'عام': <gensim.models.keyedvectors.Vocab at 0x2208e3ece80>,
#  'دراز': <gensim.models.keyedvectors.Vocab at 0x2208e41dc50>,
#  'مالکین': <gensim.models.keyedvectors.Vocab at 0x2208e370198>,
#  'هنرمندان': <gensim.models.keyedvectors.Vocab at 0x2208e43ea90>,
#  'شدبه': <gensim.models.keyedvectors.Vocab at 0x2208e490828>,
#  'عملگرا': <gensim.models.keyedvectors.Vocab at 0x2208e326da0>,
#  'مَنْ': <gensim.models.keyedvectors.Vocab at 0x2208e631550>,
#  'نفاق': <gensim.models.keyedvectors.Vocab at 0x2208e6564e0>,
#  'شکستی': <gensim.models.keyedvectors.Vocab at 0x2208e3e8b70>,
#  'خضلوزاده': <gensim.models.keyedvectors.Vocab at 0x2208e446eb8>,
#  'تمهیدات': <gensim.models.keyedvectors.Vocab at 0x2208e625a20>,
#  'مظلومان': <gensim.models.keyedvectors.Vocab at 0x2208e611278>,
#  'یارى': <gensim.models.keyedvectors.Vocab at 0x2208e6500f0>,
#  'مناقشههای': <gensim.models.keyedvectors.Vocab at 0x2208e5f2320>,
#  'بومی': <gensim.models.keyedvectors.Vocab at 0x2208e2d7b38>,
#  'بهزاد': <gensim.models.keyedvectors.Vocab at 0x2208e452940>,
#  'ماتیاس': <gensim.models.keyedvectors.Vocab at 0x2208e694400>,
#  'محتشم': <gensim.models.keyedvectors.Vocab at 0x2208e46bda0>,
#  'بحثهای': <gensim.models.keyedvectors.Vocab at 0x2208e668f98>,
#  'استفادۀ': <gensim.models.keyedvectors.Vocab at 0x2208e5579b0>,
#  'اسطوره': <gensim.models.keyedvectors.Vocab at 0x2208e656518>,
#  'فهمیدن': <gensim.models.keyedvectors.Vocab at 0x2208e4f31d0>,
#  'مترمکعبی': <gensim.models.keyedvectors.Vocab at 0x2208e60bbe0>,
#  'بکارگیری': <gensim.models.keyedvectors.Vocab at 0x2208e47d240>,
#  'جعفر': <gensim.models.keyedvectors.Vocab at 0x2208e351128>,
#  'تازهای': <gensim.models.keyedvectors.Vocab at 0x2208e452c88>,
#  'شناسانده': <gensim.models.keyedvectors.Vocab at 0x2208e644e48>,
#  'عمیقا': <gensim.models.keyedvectors.Vocab at 0x2208e589518>,
#  'نحوی': <gensim.models.keyedvectors.Vocab at 0x2208e3153c8>,
#  'سنگان': <gensim.models.keyedvectors.Vocab at 0x2208e670d30>,
#  'توقیف': <gensim.models.keyedvectors.Vocab at 0x2208e36bcf8>,
#  'پرندگان': <gensim.models.keyedvectors.Vocab at 0x2208e2c2f60>,
#  'حضرتش': <gensim.models.keyedvectors.Vocab at 0x2208e644e80>,
#  'مراغه': <gensim.models.keyedvectors.Vocab at 0x2208e618940>,
#  'برازنده': <gensim.models.keyedvectors.Vocab at 0x2208e5cdd68>,
#  'شکارا': <gensim.models.keyedvectors.Vocab at 0x2208e3a4898>,
#  'عادلی': <gensim.models.keyedvectors.Vocab at 0x2208e6d59b0>,
#  'الاوسط': <gensim.models.keyedvectors.Vocab at 0x2208e5bbf98>,
#  'مادر': <gensim.models.keyedvectors.Vocab at 0x2208e3da7f0>,
#  'میتوانم': <gensim.models.keyedvectors.Vocab at 0x2208e43e898>,
#  'سیستم': <gensim.models.keyedvectors.Vocab at 0x2208e2aa278>,
#  'گپ': <gensim.models.keyedvectors.Vocab at 0x2208e53ed68>,
#  'گورش': <gensim.models.keyedvectors.Vocab at 0x2208e57b748>,
#  'گرمایش': <gensim.models.keyedvectors.Vocab at 0x2208e5c8198>,
#  'ممنوعیت': <gensim.models.keyedvectors.Vocab at 0x2208e370cc0>,
#  'موریس': <gensim.models.keyedvectors.Vocab at 0x2208e6681d0>,
#  'مجارستان': <gensim.models.keyedvectors.Vocab at 0x2208e377668>,
#  'روى': <gensim.models.keyedvectors.Vocab at 0x2208e4a2a90>,
#  'شنا': <gensim.models.keyedvectors.Vocab at 0x2208e326860>,
#  'پیشکسوت': <gensim.models.keyedvectors.Vocab at 0x2208e43e128>,
#  'فرو': <gensim.models.keyedvectors.Vocab at 0x2208e42ba58>,
#  'حماسی': <gensim.models.keyedvectors.Vocab at 0x2208e4ce278>,
#  'شیرازی': <gensim.models.keyedvectors.Vocab at 0x2208e3da9e8>,
#  'داشتهاست': <gensim.models.keyedvectors.Vocab at 0x2208e694b00>,
#  'ینما': <gensim.models.keyedvectors.Vocab at 0x2208e625da0>,
#  'لاهوری': <gensim.models.keyedvectors.Vocab at 0x2208e5f25f8>,
#  'مرج': <gensim.models.keyedvectors.Vocab at 0x2208e57b7f0>,
#  'حیوان': <gensim.models.keyedvectors.Vocab at 0x2208e370eb8>,
#  'ضدتانک': <gensim.models.keyedvectors.Vocab at 0x2208e6cda90>,
#  'بخشها': <gensim.models.keyedvectors.Vocab at 0x2208e5db278>,
#  'رسوایی': <gensim.models.keyedvectors.Vocab at 0x2208e49b358>,
#  'ظلی': <gensim.models.keyedvectors.Vocab at 0x2208e62a550>,
#  'معلولان': <gensim.models.keyedvectors.Vocab at 0x2208e670278>,
#  'مناسب': <gensim.models.keyedvectors.Vocab at 0x2208dd3aef0>,
#  'ذری': <gensim.models.keyedvectors.Vocab at 0x2208e5afbe0>,
#  'انتظاراتی': <gensim.models.keyedvectors.Vocab at 0x2208e60b6d8>,
#  'یاد': <gensim.models.keyedvectors.Vocab at 0x2208dd1d7b8>,
#  'قرات': <gensim.models.keyedvectors.Vocab at 0x2208e458b70>,
#  'صدرنشین': <gensim.models.keyedvectors.Vocab at 0x2208e2fb860>,
#  'اقامه': <gensim.models.keyedvectors.Vocab at 0x2208e2a53c8>,
#  'تخلیه': <gensim.models.keyedvectors.Vocab at 0x2208e3a9048>,
#  'سعیدی': <gensim.models.keyedvectors.Vocab at 0x2208e437400>,
#  'گوناگونی': <gensim.models.keyedvectors.Vocab at 0x2208e390be0>,
#  'متنوعی': <gensim.models.keyedvectors.Vocab at 0x2208e3c1550>,
#  'تاکتیک': <gensim.models.keyedvectors.Vocab at 0x2208e413518>,
#  'اقّلاً': <gensim.models.keyedvectors.Vocab at 0x2208e5309b0>,
#  'فرمایید': <gensim.models.keyedvectors.Vocab at 0x2208e5172b0>,
#  'معامله': <gensim.models.keyedvectors.Vocab at 0x2208dd2d2b0>,
#  'مقرون': <gensim.models.keyedvectors.Vocab at 0x2208e67cef0>,
#  'عضدالملک': <gensim.models.keyedvectors.Vocab at 0x2208e64a978>,
#  'مبحث': <gensim.models.keyedvectors.Vocab at 0x2208e475208>,
#  'دانش': <gensim.models.keyedvectors.Vocab at 0x2208e2bda58>,
#  'روانپزشکی': <gensim.models.keyedvectors.Vocab at 0x2208e670860>,
#  'شاهینی': <gensim.models.keyedvectors.Vocab at 0x2208dd22860>,
#  'گینس': <gensim.models.keyedvectors.Vocab at 0x2208e2b6cc0>,
#  'ذیربط': <gensim.models.keyedvectors.Vocab at 0x2208e63d3c8>,
#  'سازگار': <gensim.models.keyedvectors.Vocab at 0x2208e42b278>,
#  'محک': <gensim.models.keyedvectors.Vocab at 0x2208e63d2e8>,
#  'پرسپولیس': <gensim.models.keyedvectors.Vocab at 0x2208e2e2da0>,
#  'مصاحبههایی': <gensim.models.keyedvectors.Vocab at 0x2208e4a26d8>,
#  'ناشناخته': <gensim.models.keyedvectors.Vocab at 0x2208e35f7b8>,
#  'ماهواره': <gensim.models.keyedvectors.Vocab at 0x2208e3e2208>,
#  'کاران': <gensim.models.keyedvectors.Vocab at 0x2208e5a3b38>,
#  'بازوان': <gensim.models.keyedvectors.Vocab at 0x2208e620c18>,
#  'خونبار': <gensim.models.keyedvectors.Vocab at 0x2208e5a3780>,
#  'سرمایهگذاری': <gensim.models.keyedvectors.Vocab at 0x2208e488588>,
#  'کلونی': <gensim.models.keyedvectors.Vocab at 0x2208e437da0>,
#  'طریقت': <gensim.models.keyedvectors.Vocab at 0x2208e4f91d0>,
#  'لومینیوم': <gensim.models.keyedvectors.Vocab at 0x2208e3f3e10>,
#  'درخواستها': <gensim.models.keyedvectors.Vocab at 0x2208e60bcf8>,
#  'جمله': <gensim.models.keyedvectors.Vocab at 0x2208dd28240>,
#  'وارد': <gensim.models.keyedvectors.Vocab at 0x2208dd3a400>,
#  'گلچین': <gensim.models.keyedvectors.Vocab at 0x2208e5ee208>,
#  'پرسرعت': <gensim.models.keyedvectors.Vocab at 0x2208e6e1898>,
#  'بصره': <gensim.models.keyedvectors.Vocab at 0x2208e5bbb00>,
#  'بورکینافاسو': <gensim.models.keyedvectors.Vocab at 0x2208e63dcc0>,
#  'سیای': <gensim.models.keyedvectors.Vocab at 0x2208e351c50>,
#  'انداختن': <gensim.models.keyedvectors.Vocab at 0x2208e4ce320>,
#  'اینتل': <gensim.models.keyedvectors.Vocab at 0x2208e6aff60>,
#  'تاید': <gensim.models.keyedvectors.Vocab at 0x2208e49bd30>,
#  'رویی': <gensim.models.keyedvectors.Vocab at 0x2208e6c1358>,
#  'ستادی': <gensim.models.keyedvectors.Vocab at 0x2208e44ac18>,
#  'بنماید': <gensim.models.keyedvectors.Vocab at 0x2208e6c8668>,
#  ...}

# %%
w2v = np.zeros((max_size,model.layer1_size))
# Out:
# E:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `layer1_size` (Attribute will be removed in 4.0.0, use self.trainables.layer1_size instead).
#   """Entry point for launching an IPython kernel.

# %%
with open("metadata.tsv", 'w+') as file_metadata:
    for i,word in enumerate(model.wv.index2word[:max_size]):
        w2v[i] = model.wv[word]
        file_metadata.write(word + '\n')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-6-b52045be9c08> in <module>()
#       2     for i,word in enumerate(model.wv.index2word[:max_size]):
#       3         w2v[i] = model.wv[word]
# ----> 4         file_metadata.write(word + '\n')
#
# E:\Anaconda\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 0-2: character maps to <undefined>

# %%
sess = tf.InteractiveSession()

# %%
#Let us create a 2D tensor called embedding that holds our embeddings.
with tf.device("/cpu:0"):
    embedding = tf.Variable(w2v, trainable=False, name='embedding')

# %%
tf.global_variables_initializer().run()

# %%
path = 'w3v'

# %%
# let us create an object to Saver class which is actually used to 
#save and restore variables to and from our checkpoints
saver = tf.train.Saver()

# %%
# using file writer, we can save our summaries and events to our event file.
writer = tf.summary.FileWriter(path, sess.graph)

# %%
# adding into projector
config = projector.ProjectorConfig()
embed = config.embeddings.add()
embed.tensor_name = 'embedding'
embed.metadata_path = 'metadata.tsv'

# %%
# Specify the width and height of a single thumbnail.
projector.visualize_embeddings(writer, config)

saver.save(sess, path+'/model.ckpt', global_step=max_size)
# Out:
# 'w3v/model.ckpt-13514'
